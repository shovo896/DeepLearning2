# %%
import tensorflow as tf
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.mobilenet_v2 import preprocess_input, decode_predictions
import numpy as np
import matplotlib.pyplot as plt

# %%
model = MobileNetV2(weights="imagenet")
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224.h5
# 14536120/14536120 ━━━━━━━━━━━━━━━━━━━━ 23s 2us/step

# %%
import cv2


img = cv2.imread("water_detector.jpeg")

if img is None:
    print("Image not found!")
else:
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)  # Convert BGR → RGB
    plt.imshow(img)
    plt.axis('off')
    plt.show()

# %%
from tensorflow.keras.preprocessing import image
import matplotlib.pyplot as plt
import numpy as np

img = image.load_img("water_detector.jpeg", target_size=(224, 224))

x = image.img_to_array(img)  # Convert PIL → NumPy array
x = x.astype("uint8")  # Now we can apply astype

plt.imshow(x)
plt.axis('off')
plt.show()

# %%
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

# Make predictions
preds = model.predict(x)
print('Predicted:', decode_predictions(preds, top=3)[0])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# Predicted: [('n03794056', 'mousetrap', np.float32(0.10376081)), ('n03584254', 'iPod', np.float32(0.065826505)), ('n03777754', 'modem', np.float32(0.044448677))]
